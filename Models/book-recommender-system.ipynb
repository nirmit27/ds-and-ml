# %% [markdown]
# <a href="https://www.kaggle.com/code/nirmit27/book-recommender-system?scriptVersionId=163577974" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np
import pandas as pd

# For Collaborative Filtering
from sklearn.metrics.pairwise import cosine_similarity as cos_sim

# %% [markdown]
# ## Importing the **datasets**

# %%
books = pd.read_csv('/kaggle/input/book-recommendation-dataset/Books.csv')
users = pd.read_csv('/kaggle/input/book-recommendation-dataset/Users.csv')
ratings = pd.read_csv('/kaggle/input/book-recommendation-dataset/Ratings.csv')
# Out:
# /tmp/ipykernel_18/2910231406.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('/kaggle/input/book-recommendation-dataset/Books.csv')

# %% [markdown]
# ## Image **URLs** updation

# %%
books['Image-URL-S'] = books['Image-URL-S'].str.replace('http', 'https')
books['Image-URL-M'] = books['Image-URL-M'].str.replace('http', 'https')
books['Image-URL-L'] = books['Image-URL-L'].str.replace('http', 'https')

books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  https://images.amazon.com/images/P/0195153448....
# 1  https://images.amazon.com/images/P/0002005018....
# 2  https://images.amazon.com/images/P/0060973129....
# 3  https://images.amazon.com/images/P/0374157065....
# 4  https://images.amazon.com/images/P/0393045218....
#
#                                          Image-URL-M  \
# 0  https://images.amazon.com/images/P/0195153448....
# 1  https://images.amazon.com/images/P/0002005018....
# 2  https://images.amazon.com/images/P/0060973129....
# 3  https://images.amazon.com/images/P/0374157065....
# 4  https://images.amazon.com/images/P/0393045218....
#
#                                          Image-URL-L
# 0  https://images.amazon.com/images/P/0195153448....
# 1  https://images.amazon.com/images/P/0002005018....
# 2  https://images.amazon.com/images/P/0060973129....
# 3  https://images.amazon.com/images/P/0374157065....
# 4  https://images.amazon.com/images/P/0393045218....

# %% [markdown]
# # Data **Preprocessing**

# %% [markdown]
# ## Converting **dates**

# %%
books['Year-Of-Publication'] = pd.to_datetime(books['Year-Of-Publication'], errors='coerce')
books['Year-Of-Publication'] = books['Year-Of-Publication'].fillna(books['Year-Of-Publication'].mean())
books['Year-Of-Publication'] = books['Year-Of-Publication'].astype(np.int64)

books['Year-Of-Publication']
# Out:
# 0         2002
# 1         2001
# 2         1991
# 3         1999
# 4         1999
#           ...
# 271355    1988
# 271356    1991
# 271357    2004
# 271358    1996
# 271359    2000
# Name: Year-Of-Publication, Length: 271360, dtype: int64

# %% [markdown]
# ## **Merging** `books_data` and `ratings`

# %%
books_data_ratings = books.merge(ratings, on='ISBN')

books_data_ratings.shape
# Out:
# (1031136, 10)

# %% [markdown]
# ## Average ratings

# %%
avg_ratings = books_data_ratings.groupby('Book-Title')['Book-Rating'].mean().sort_values(ascending=False).reset_index()
avg_ratings.rename(columns={'Book-Rating': 'avg_rating'}, inplace=True)

avg_ratings
# Out:
#                                                Book-Title  avg_rating
# 0                  Film Is: The International Free Cinema        10.0
# 1       More Secrets of Happy Children: Embrace Your P...        10.0
# 2                 Jo's Boys : From the Original Publisher        10.0
# 3         The Vanished Priestess : An Annie Szabo Mystery        10.0
# 4                                        Game and Hunting        10.0
# ...                                                   ...         ...
# 241066  Invaders of the Planet Earth (Choose Your Own ...         0.0
# 241067    Sammy Discovers the Alphabet (Learn-With-Sammy)         0.0
# 241068                    Sammy Carducci's Guide to Women         0.0
# 241069  Sammle mir Kiesel am FluÃ?Â?. Mehr als eine Li...         0.0
# 241070                                     TRAVELLING MAN         0.0
#
# [241071 rows x 2 columns]

# %% [markdown]
# ## Number of ratings

# %%
num_ratings = books_data_ratings.groupby('Book-Title')['Book-Rating'].count().sort_values(ascending=False).reset_index()
num_ratings.rename(columns={'Book-Rating': 'num_rating'}, inplace=True)

num_ratings
# Out:
#                                                Book-Title  num_rating
# 0                                             Wild Animus        2502
# 1                               The Lovely Bones: A Novel        1295
# 2                                       The Da Vinci Code         898
# 3                                         A Painted House         838
# 4                              The Nanny Diaries: A Novel         828
# ...                                                   ...         ...
# 241066  Real Love: The Truth About Finding Uncondition...           1
# 241067                   Real Love: The Drawings for Sean           1
# 241068  Real Love or Fake (Camfield Novel of Love, No 78)           1
# 241069  Fabulous Food for Family and Friends: Healthy ...           1
# 241070  Suburban backlash: The battle for the world's ...           1
#
# [241071 rows x 2 columns]

# %% [markdown]
# ## Merging the data of **ratings** into one table

# %%
merged = num_ratings.merge(avg_ratings, on='Book-Title').sort_values(by='avg_rating', ascending=False)
merged
# Out:
#                                                Book-Title  num_rating  \
# 131743  The Adventures and Memoirs of Sherlock Holmes ...           1
# 152099  Unexpected News: Reading the Bible With Third ...           1
# 152134                A pictorial history of sex in films           1
# 86504     The Violet Keystone (The Seventh Tower, Book 6)           2
# 222327  Stick and Rudder: An Explanation of the Art of...           1
# ...                                                   ...         ...
# 136778           Confessions To My Mother-Cathy Guisewite           1
# 136777                Confessions Dun Porte Drapeau Dechu           1
# 136776                                     Confess-O-Rama           1
# 136775                    Writing and Analysis in the Law           1
# 241070  Suburban backlash: The battle for the world's ...           1
#
#         avg_rating
# 131743        10.0
# 152099        10.0
# 152134        10.0
# 86504         10.0
# 222327        10.0
# ...            ...
# 136778         0.0
# 136777         0.0
# 136776         0.0
# 136775         0.0
# 241070         0.0
#
# [241071 rows x 3 columns]

# %% [markdown]
# ## Filter for `num_rating >= 250` **sorted** by `avg_rating`
# ------------------------------------------------------------
# ### We'll use this data for **Top 50** books' content.

# %%
popular_books = merged[merged['num_rating'] >= 250].sort_values(by='avg_rating', ascending=False)
popular_books = popular_books.merge(books, on='Book-Title').drop_duplicates('Book-Title')

top_50 = popular_books[popular_books['num_rating'] >= 250][['Book-Title', 'Book-Author', 'Image-URL-M', 'num_rating', 'avg_rating']]
top_50.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 186 entries, 0 to 739
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Book-Title   186 non-null    object
#  1   Book-Author  186 non-null    object
#  2   Image-URL-M  186 non-null    object
#  3   num_rating   186 non-null    int64
#  4   avg_rating   186 non-null    float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 8.7+ KB

# %% [markdown]
# # **Collaborative Filtering**
# -----------------------------
# ### Building the **Recommender System** model

# %% [markdown]
# ### Finding users who have rated **over 200** books

# %%
chosen_ratings = books_data_ratings.groupby('User-ID').count()['Book-Rating'] > 200
chosen_users = chosen_ratings[chosen_ratings].index
chosen_users
# Out:
# Index([   254,   2276,   2766,   2977,   3363,   4017,   4385,   6251,   6323,
#          6543,
#        ...
#        271705, 273979, 274004, 274061, 274301, 274308, 275970, 277427, 277639,
#        278418],
#       dtype='int64', name='User-ID', length=811)

# %% [markdown]
# ### **Filtering** out the ratings from the **chosen users** ONLY

# %%
filtered_ratings = books_data_ratings[books_data_ratings['User-ID'].isin(chosen_users)]
filtered_ratings
# Out:
#                ISBN                                         Book-Title  \
# 3        0002005018                                       Clara Callan
# 6        0002005018                                       Clara Callan
# 7        0002005018                                       Clara Callan
# 10       0002005018                                       Clara Callan
# 21       0374157065  Flu: The Story of the Great Influenza Pandemic...
# ...             ...                                                ...
# 1031124  0231128444                      Slow Food(The Case For Taste)
# 1031125  0520242335  Strong Democracy : Participatory Politics for ...
# 1031126  0762412119  Burpee Gardening Cyclopedia: A Concise, Up to ...
# 1031127  1582380805  Tropical Rainforests: 230 Species in Full Colo...
# 1031128  1845170423                                  Cocktail Classics
#
#                    Book-Author  Year-Of-Publication  \
# 3         Richard Bruce Wright                 2001
# 6         Richard Bruce Wright                 2001
# 7         Richard Bruce Wright                 2001
# 10        Richard Bruce Wright                 2001
# 21            Gina Bari Kolata                 1999
# ...                        ...                  ...
# 1031124          Carlo Petrini                 2003
# 1031125     Benjamin R. Barber                 2004
# 1031126         Allan Armitage                 2002
# 1031127  Allen M., Ph.D. Young                 2001
# 1031128            David Biggs                 2004
#
#                                      Publisher  \
# 3                        HarperFlamingo Canada
# 6                        HarperFlamingo Canada
# 7                        HarperFlamingo Canada
# 10                       HarperFlamingo Canada
# 21                        Farrar Straus Giroux
# ...                                        ...
# 1031124              Columbia University Press
# 1031125         University of California Press
# 1031126          Running Press Book Publishers
# 1031127  Golden Guides from St. Martin's Press
# 1031128                              Connaught
#
#                                                Image-URL-S  \
# 3        https://images.amazon.com/images/P/0002005018....
# 6        https://images.amazon.com/images/P/0002005018....
# 7        https://images.amazon.com/images/P/0002005018....
# 10       https://images.amazon.com/images/P/0002005018....
# 21       https://images.amazon.com/images/P/0374157065....
# ...                                                    ...
# 1031124  https://images.amazon.com/images/P/0231128444....
# 1031125  https://images.amazon.com/images/P/0520242335....
# 1031126  https://images.amazon.com/images/P/0762412119....
# 1031127  https://images.amazon.com/images/P/1582380805....
# 1031128  https://images.amazon.com/images/P/1845170423....
#
#                                                Image-URL-M  \
# 3        https://images.amazon.com/images/P/0002005018....
# 6        https://images.amazon.com/images/P/0002005018....
# 7        https://images.amazon.com/images/P/0002005018....
# 10       https://images.amazon.com/images/P/0002005018....
# 21       https://images.amazon.com/images/P/0374157065....
# ...                                                    ...
# 1031124  https://images.amazon.com/images/P/0231128444....
# 1031125  https://images.amazon.com/images/P/0520242335....
# 1031126  https://images.amazon.com/images/P/0762412119....
# 1031127  https://images.amazon.com/images/P/1582380805....
# 1031128  https://images.amazon.com/images/P/1845170423....
#
#                                                Image-URL-L  User-ID  \
# 3        https://images.amazon.com/images/P/0002005018....    11676
# 6        https://images.amazon.com/images/P/0002005018....    85526
# 7        https://images.amazon.com/images/P/0002005018....    96054
# 10       https://images.amazon.com/images/P/0002005018....   177458
# 21       https://images.amazon.com/images/P/0374157065....   110912
# ...                                                    ...      ...
# 1031124  https://images.amazon.com/images/P/0231128444....   275970
# 1031125  https://images.amazon.com/images/P/0520242335....   275970
# 1031126  https://images.amazon.com/images/P/0762412119....   275970
# 1031127  https://images.amazon.com/images/P/1582380805....   275970
# 1031128  https://images.amazon.com/images/P/1845170423....   275970
#
#          Book-Rating
# 3                  8
# 6                  0
# 7                  0
# 10                 0
# 21                10
# ...              ...
# 1031124            0
# 1031125            0
# 1031126            0
# 1031127            0
# 1031128            7
#
# [474007 rows x 10 columns]

# %% [markdown]
# ### **Book titles** having **more than 50** ratings

# %%
filter_book_titles = filtered_ratings.groupby('Book-Title').count()['Book-Rating'] >= 50
famous_books = filter_book_titles[filter_book_titles].index
famous_books
# Out:
# Index(['1984', '1st to Die: A Novel', '2nd Chance', '4 Blondes',
#        'A Bend in the Road', 'A Case of Need',
#        'A Child Called \It\": One Child's Courage to Survive"',
#        'A Civil Action', 'A Day Late and a Dollar Short', 'A Fine Balance',
#        ...
#        'Winter Solstice', 'Wish You Well', 'Without Remorse',
#        'Wizard and Glass (The Dark Tower, Book 4)', 'Wuthering Heights',
#        'Year of Wonders', 'You Belong To Me',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"'],
#       dtype='object', name='Book-Title', length=706)

# %% [markdown]
# ### **Filtering** out the books that have **more than 50** ratings

# %%
final_df = filtered_ratings[filtered_ratings['Book-Title'].isin(famous_books)]
final_df.tail()
# Out:
#                ISBN                       Book-Title      Book-Author  \
# 1028414  1878702831                           Echoes      Nancy Morse
# 1028600  0394429869  I Know Why the Caged Bird Sings     Maya Angelou
# 1028602  0449001164                      The Promise      CHAIM POTOK
# 1028815  0743527631         The Pillars of the Earth      Ken Follett
# 1028817  0745168086              The Handmaid's Tale  Margaret Atwood
#
#          Year-Of-Publication                      Publisher  \
# 1028414                 1992  Meteor Publishing Corporation
# 1028600                 1996                   Random House
# 1028602                 1997               Ballantine Books
# 1028815                 2002                         Encore
# 1028817                 1999            Chivers Audio Books
#
#                                                Image-URL-S  \
# 1028414  https://images.amazon.com/images/P/1878702831....
# 1028600  https://images.amazon.com/images/P/0394429869....
# 1028602  https://images.amazon.com/images/P/0449001164....
# 1028815  https://images.amazon.com/images/P/0743527631....
# 1028817  https://images.amazon.com/images/P/0745168086....
#
#                                                Image-URL-M  \
# 1028414  https://images.amazon.com/images/P/1878702831....
# 1028600  https://images.amazon.com/images/P/0394429869....
# 1028602  https://images.amazon.com/images/P/0449001164....
# 1028815  https://images.amazon.com/images/P/0743527631....
# 1028817  https://images.amazon.com/images/P/0745168086....
#
#                                                Image-URL-L  User-ID  \
# 1028414  https://images.amazon.com/images/P/1878702831....   238781
# 1028600  https://images.amazon.com/images/P/0394429869....   239594
# 1028602  https://images.amazon.com/images/P/0449001164....   239594
# 1028815  https://images.amazon.com/images/P/0743527631....   240144
# 1028817  https://images.amazon.com/images/P/0745168086....   240144
#
#          Book-Rating
# 1028414            0
# 1028600            8
# 1028602            7
# 1028815            0
# 1028817            0

# %% [markdown]
# ### **Processing** the final subset of data
# -------------------------------------------
# **Pivoting** the table on the `Book-Title` as **index**, `User-ID` as **columns** with `Book-Rating` as **values**.

# %%
pt = final_df.pivot_table(index='Book-Title', columns='User-ID', values='Book-Rating').fillna(0.0)
pt.index
# Out:
# Index(['1984', '1st to Die: A Novel', '2nd Chance', '4 Blondes',
#        'A Bend in the Road', 'A Case of Need',
#        'A Child Called \It\": One Child's Courage to Survive"',
#        'A Civil Action', 'A Day Late and a Dollar Short', 'A Fine Balance',
#        ...
#        'Winter Solstice', 'Wish You Well', 'Without Remorse',
#        'Wizard and Glass (The Dark Tower, Book 4)', 'Wuthering Heights',
#        'Year of Wonders', 'You Belong To Me',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"'],
#       dtype='object', name='Book-Title', length=706)

# %% [markdown]
# ### Computing the **cosine similarity scores** of the books
# We are computing the **Euclidean distances** of **706** books from **706** books.

# %%
sims = cos_sim(pt)
sims
# Out:
# array([[1.        , 0.10255025, 0.01220856, ..., 0.12110367, 0.07347567,
#         0.04316046],
#        [0.10255025, 1.        , 0.2364573 , ..., 0.07446129, 0.16773875,
#         0.14263397],
#        [0.01220856, 0.2364573 , 1.        , ..., 0.04558758, 0.04938579,
#         0.10796119],
#        ...,
#        [0.12110367, 0.07446129, 0.04558758, ..., 1.        , 0.07085128,
#         0.0196177 ],
#        [0.07347567, 0.16773875, 0.04938579, ..., 0.07085128, 1.        ,
#         0.10602962],
#        [0.04316046, 0.14263397, 0.10796119, ..., 0.0196177 , 0.10602962,
#         1.        ]])

# %% [markdown]
# ### **Recommender** function
# This function will ***suggest*** the **top 5** books based on their **similarity scores** closest to the **given** book.

# %%
def recommend(book_name):
    
    suggestions = []
    
    # Fetching the book's index number
    i = np.where(pt.index == book_name)[0][0]
    
    # Fetching the similarity scores
    top_5_scores = sorted(list(enumerate(sims[i])), key=lambda x: x[1], reverse=True)[1:6]
    
    # Fetching the book title suggestions that match the similarity scores
    for i in sorted(list(enumerate(sims[i])), key=lambda x: x[1], reverse=True)[1:6]:
        suggestions.append(pt.index[i[0]])
    
    return suggestions

# %% [markdown]
# ### **Output**
# --------------
# 1. Table of **top 5** suggestions for each of the **706 most famous** books.
# 2. Table of **top-rated** books with their **image urls**.

# %%
all_suggestions = {}

for name in pt.index:
    all_suggestions.update({name: recommend(name)})
    
suggestions_df = pd.DataFrame(all_suggestions).T
suggestions_df.rename(columns={0: "1st", 1: "2nd", 2: "3rd", 3: "4th", 4: "5th"}, inplace=True)

suggestions_df.to_csv('suggestions.csv')
top_50.to_csv('top50.csv')
